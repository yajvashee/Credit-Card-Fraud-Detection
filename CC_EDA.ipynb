# %% [markdown]
# ### 1. Importing Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# %% [markdown]
# ### 2. Loading the Dataset

# %%
df=pd.read_csv("data/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ### 3. Dataset Overview

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %% [markdown]
# ### 4. Understanding Data Types

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# Where:
#
# 0 → Legitimate Transaction
# 1 → Fraudulent Transaction

# %%
duplicates = df.duplicated().sum()
print("Duplicate rows:", duplicates)
# Out:
# Duplicate rows: 1081

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (283726, 31)

# %% [markdown]
# Duplicate fraudulent transactions can bias the model.

# %%
df.columns.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Check Feature Variance

# %%
variance = df.var().sort_values()
variance
# Out:
# Class     1.664328e-03
# V28       1.076015e-01
# V27       1.566132e-01
# V26       2.323750e-01
# V25       2.716706e-01
# V24       3.667837e-01
# V23       3.890047e-01
# V21       5.240448e-01
# V22       5.249734e-01
# V20       5.928757e-01
# V19       6.615847e-01
# V18       7.012011e-01
# V17       7.098186e-01
# V16       7.633453e-01
# V15       8.370304e-01
# V14       9.067136e-01
# V12       9.893773e-01
# V13       9.908802e-01
# V11       1.037791e+00
# V10       1.158653e+00
# V9        1.200104e+00
# V8        1.390169e+00
# V7        1.507159e+00
# V6        1.774039e+00
# V5        1.896152e+00
# V4        1.999916e+00
# V3        2.276121e+00
# V2        2.711631e+00
# V1        3.794806e+00
# Amount    6.269988e+04
# Time      2.254450e+09
# dtype: float64

# %% [markdown]
# Every predictor (V1–V28, Amount, and Time) has a variance greater than zero.
# Therefore, every feature contains some variation and potentially useful information.
#
# The large variances for Amount and especially Time are expected because:
#
# Amount is measured in currency units and spans a wide range.
# Time is measured in seconds over approximately 48 hours (0–172,800 seconds).
#
# The PCA features (V1–V28) have much smaller variances because they are transformed features on a standardized scale.

# %% [markdown]
# ### 5. Relationship Analysis

# %% [markdown]
# ### 1. Univariate Analysis

# %% [markdown]
# Histograms of PCA Features
# Observation: The histograms indicate that most PCA-transformed features (V1–V28) are approximately centered around zero. This is expected because PCA is typically applied to standardized data, resulting in principal components with means close to zero. Several components exhibit roughly bell-shaped distributions, although some display skewness and outliers. The Amount feature remains highly right-skewed, while Time follows a temporal pattern rather than a normal distribution.

# %%
df.hist(figsize=(18,18))

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.hist(df["Time"], bins=50)

plt.title("Distribution of Transaction Time")
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(10,5))
plt.hist(df["Amount"], bins=50)

plt.title("Distribution of Transaction Amount")
plt.xlabel("Amount")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# Class Distribution

# %%
import matplotlib.pyplot as plt

class_counts = df["Class"].value_counts()

plt.figure(figsize=(6,4))
plt.bar(class_counts.index.astype(str), class_counts.values)
plt.title("Class Distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %% [markdown]
# Notice the difference:
#
# Class 0 → 283253
# Class 1 → 473
#
# The legitimate transactions are about 500+ times more frequent than fraudulent transactions.
#
# Because the bar for class 1 is so tiny compared to class 0, it looks like it doesn't exist.

# %% [markdown]
# Fraud Percentage

# %%
fraud_percentage = df["Class"].value_counts(normalize=True)*100
fraud_percentage
# Out:
# Class
# 0    99.83329
# 1     0.16671
# Name: proportion, dtype: float64

# %% [markdown]
# Percentage Distribution (Pie Chart)

# %%
import matplotlib.pyplot as plt

labels = ["Legitimate", "Fraud"]

sizes = df["Class"].value_counts(normalize=True)

plt.figure(figsize=(6,6))

plt.pie(
    sizes,
    labels=labels,
    autopct="%1.2f%%",
    startangle=90
)

plt.title("Transaction Class Distribution")

plt.show()

# %% [markdown]
# The fraud slice is barely visible because fraudulent transactions account for only about 0.17% of the dataset. This extreme imbalance is why accuracy alone is not an appropriate evaluation metric

# %% [markdown]
# Distribution of Amount

# %% [markdown]
# ### Bivariate Analysis

# %%
plt.figure(figsize=(8,5))

plt.boxplot(
    [
        df[df["Class"] == 0]["Amount"],
        df[df["Class"] == 1]["Amount"]
    ],
    tick_labels=["Legitimate", "Fraud"]
)

plt.title("Transaction Amount by Class")
plt.ylabel("Amount")

plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df["Amount"], vert=False)
plt.title("Boxplot of Transaction Amount")
plt.show()
# Out:
# C:\Users\Geeth\AppData\Local\Temp\ipykernel_14444\2679203197.py:2: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(df["Amount"], vert=False)

# %% [markdown]
# Large number of outliers. Fraud usually occurs in unusual amounts.

# %% [markdown]
# Fraud vs Legit Amount

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.boxplot(
    [
        df[df["Class"] == 0]["Amount"],
        df[df["Class"] == 1]["Amount"]
    ],
    tick_labels=["Legitimate", "Fraud"]
)

plt.title("Transaction Amount by Class")
plt.ylabel("Transaction Amount")

plt.show()

# %% [markdown]
# ### Time vs Class

# %%
plt.figure(figsize=(10,5))

plt.scatter(
    df["Time"],
    df["Class"],
    alpha=0.2,
    s=10
)

plt.title("Transaction Time vs Class")
plt.xlabel("Time (seconds)")
plt.ylabel("Class")

plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# Pairplot

# %% [markdown]
# A pairplot allows you to examine the relationships between pairs of variables and how well the classes (fraud vs. non-fraud) are separated.
#
# Observation: The pairplot of selected PCA features (V1, V2, V3, and V4) indicates varying degrees of separation between fraudulent and legitimate transactions. Some feature combinations show distinct clustering of the two classes, suggesting that these variables contain discriminative information useful for fraud detection. However, there is also overlap between the classes, indicating that no single feature can perfectly distinguish fraudulent from legitimate transactions. This supports the use of machine learning models that can learn patterns from multiple features simultaneously.

# %%
import seaborn as sns

sample = df.sample(1000)

sns.pairplot(sample[['V1','V2','V3','V4','Class']], hue='Class')

# %%
plt.figure(figsize=(10,6))

plt.scatter(
    df[df["Class"]==0]["Time"],
    df[df["Class"]==0]["Amount"],
    alpha=0.2,
    s=10,
    label="Legitimate"
)

plt.scatter(
    df[df["Class"]==1]["Time"],
    df[df["Class"]==1]["Amount"],
    alpha=0.8,
    s=20,
    label="Fraud"
)

plt.xlabel("Time")
plt.ylabel("Amount")
plt.title("Time vs Amount by Transaction Class")

plt.legend()

plt.show()

# %% [markdown]
# ### Remove Outliers (>20,000)

# %%
df_amount_20000 = df[df["Amount"] <= 20000]

plt.figure(figsize=(10,5))

plt.hist(df_amount_20000["Amount"], bins=50)

plt.title("Transaction Amount (<=20000)")
plt.xlabel("Amount")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ### Remove Outliers (>10,000)

# %%
df_amount_10000 = df[df["Amount"] <= 10000]

plt.figure(figsize=(10,5))

plt.hist(df_amount_10000["Amount"], bins=50)

plt.title("Transaction Amount (<=10000)")
plt.xlabel("Amount")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# Removing extremely large values makes the distribution of typical transactions easier to see. This is only for visualization, not for deleting data.

# %% [markdown]
# ### Class-wise Time Distribution

# %%
plt.figure(figsize=(10,5))

plt.hist(
    df[df["Class"]==0]["Time"],
    bins=50,
    alpha=0.6,
    label="Legitimate"
)

plt.hist(
    df[df["Class"]==1]["Time"],
    bins=50,
    alpha=0.6,
    label="Fraud"
)

plt.xlabel("Time (seconds)")
plt.ylabel("Frequency")
plt.title("Transaction Time by Class")

plt.legend()

plt.show()

# %% [markdown]
# ### Class-wise Amount Distribution

# %%
plt.figure(figsize=(10,5))

plt.hist(
    df[df["Class"]==0]["Amount"],
    bins=50,
    alpha=0.6,
    label="Legitimate"
)

plt.hist(
    df[df["Class"]==1]["Amount"],
    bins=50,
    alpha=0.6,
    label="Fraud"
)

plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.title("Transaction Amount by Class")

plt.legend()

plt.show()

# %% [markdown]
# ### Correlation Matrix

# %%
import matplotlib.pyplot as plt
import numpy as np

corr = df.corr()

fig, ax = plt.subplots(figsize=(16,14))

im = ax.imshow(corr, cmap="coolwarm")

ax.set_xticks(np.arange(len(corr.columns)))
ax.set_yticks(np.arange(len(corr.columns)))

ax.set_xticklabels(corr.columns, rotation=90)
ax.set_yticklabels(corr.columns)

for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        ax.text(
            j,
            i,
            f"{corr.iloc[i,j]:.2f}",
            ha="center",
            va="center",
            fontsize=5,
            color="black"
        )

plt.colorbar(im)

plt.title("Correlation Matrix")

plt.show()

# %% [markdown]
# Because there are 31 features (Time, Amount, V1–V28, Class), the text will be very crowded.

# %% [markdown]
# Most PCA variables have low correlation. No multicollinearity problem.

# %% [markdown]
# ### Correlation with Target

# %%
corr_target = df.corr()["Class"].sort_values()
corr_target
# Out:
# V17      -0.326481
# V14      -0.302544
# V12      -0.260593
# V10      -0.216883
# V16      -0.196539
# V3       -0.192961
# V7       -0.187257
# V18      -0.111485
# V1       -0.101347
# V9       -0.097733
# V5       -0.094974
# V6       -0.043643
# Time     -0.012323
# V24      -0.007221
# V13      -0.004570
# V15      -0.004223
# V23      -0.002685
# V22       0.000805
# V25       0.003308
# V26       0.004455
# Amount    0.005632
# V28       0.009536
# V27       0.017580
# V8        0.019875
# V20       0.020090
# V19       0.034783
# V21       0.040413
# V2        0.091289
# V4        0.133447
# V11       0.154876
# Class     1.000000
# Name: Class, dtype: float64

# %%
corr_target.plot(kind="bar", figsize=(10,5))

plt.title("Correlation with Target")

plt.show()

# %%
corr_class = df.corr()[["Class"]].sort_values(by="Class", ascending=False)

plt.figure(figsize=(6,10))

plt.imshow(corr_class, cmap="coolwarm", aspect="auto")

plt.yticks(range(len(corr_class.index)), corr_class.index)
plt.xticks([0], ["Class"])

for i in range(len(corr_class.index)):
    plt.text(
        0,
        i,
        f"{corr_class.iloc[i,0]:.2f}",
        ha="center",
        va="center",
        color="black"
    )

plt.colorbar()

plt.title("Correlation with Target")

plt.show()
